# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv("spotify_data_1986_2023.csv")

# %%
df["available_markets_clean"] = df["available_markets"].str.replace(";", "", regex=False)
df["market_count"] = df["available_markets_clean"].str.len() / 2
df
# Out:
#        Unnamed: 0.1  Unnamed: 0                track_id  \
# 0                 0           0  2A6yzRGMgSQCUapR2ptm6A
# 1                 1           1  3gKwVWwKmeuFtPubICbOGc
# 2                 2           2  2tY1gxCKslfXLFpFofYmJQ
# 3                 3           3  31dqpLUModJWNbxrXu6TWd
# 4                 4           4  00vYs0qZA40Z8AAaN7xmMO
# ...             ...         ...                     ...
# 11445         11445         595  4nrPB8O7Y7wsOCJdgXkthe
# 11446         11446         596  7Lkxvfl2rkNYWS4kBDCQtN
# 11447         11447         597  6UoKX6uLJwhsnyTp5k5StP
# 11448         11448         598  4ZYAU4A2YBtlNdqOUtc7T2
# 11449         11449         599  5vZoQQ1hH5L2s4Y8G86ksg
#
#                                   track_name  popularity  \
# 0                                True Colors          73
# 1                                Paul Revere          61
# 2                               Brass Monkey          68
# 3                           Shot in the Dark          66
# ...

# %%
droplist = ["Unnamed: 0.1", ]

df = df.drop(droplist)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = df.drop("unnamed: 0")
#       2 df
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...
